# %% [markdown]
# # Visualizations
#
# This notebook presents various visualizations by interpreting data and
# relationships from the dataset.

# %%
import pandas as pd

df = pd.read_csv('datasets/tmdb-15000-movies.csv', lineterminator='\n')
